# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_phishing.csv")
df.head()
# Out:
#                                                  url  length_url  \
# 0              http://www.crestonwood.com/router.php          37
# 1  http://shadetreetechnology.com/V4/validation/a...          77
# 2  https://support-appleld.com.secureupdate.duila...         126
# 3                                 http://rgipt.ac.in          18
# 4  http://www.iracing.com/tracks/gateway-motorspo...          55
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        3           0      0      0       0      0  ...
# 1               23   1        1           0      0      0       0      0  ...
# 2               50   1        4           1      0      1       2      0  ...
# 3               11   0        2           0      0      0       0      0  ...
# 4               15   0        2           2      0      0       0      0  ...
#
#    domain_in_title  domain_with_copyright  whois_registered_domain  \
# ...

# %%
df.isnull().sum()
# Out:
# url                0
# length_url         0
# length_hostname    0
# ip                 0
# nb_dots            0
#                   ..
# web_traffic        0
# dns_record         0
# google_index       0
# page_rank          0
# status             0
# Length: 89, dtype: int64

# %%
#There is no missing value or ull value in the dataset.

# %%
df.describe()
# Out:
#          length_url  length_hostname            ip       nb_dots  \
# count  11430.000000     11430.000000  11430.000000  11430.000000
# mean      61.126684        21.090289      0.150569      2.480752
# std       55.297318        10.777171      0.357644      1.369686
# min       12.000000         4.000000      0.000000      1.000000
# 25%       33.000000        15.000000      0.000000      2.000000
# 50%       47.000000        19.000000      0.000000      2.000000
# 75%       71.000000        24.000000      0.000000      3.000000
# max     1641.000000       214.000000      1.000000     24.000000
#
#          nb_hyphens         nb_at         nb_qm        nb_and    nb_or  \
# count  11430.000000  11430.000000  11430.000000  11430.000000  11430.0
# mean       0.997550      0.022222      0.141207      0.162292      0.0
# std        2.087087      0.155500      0.364456      0.821337      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# ...

# %%
df.status.value_counts()
# Out:
# legitimate    5715
# phishing      5715
# Name: status, dtype: int64

# %%
df1 = df.drop("url" , axis = "columns")
df1.head()
# Out:
#    length_url  length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  \
# 0          37               19   0        3           0      0      0       0
# 1          77               23   1        1           0      0      0       0
# 2         126               50   1        4           1      0      1       2
# 3          18               11   0        2           0      0      0       0
# 4          55               15   0        2           2      0      0       0
#
#    nb_or  nb_eq  ...  domain_in_title  domain_with_copyright  \
# 0      0      0  ...                0                      1
# 1      0      0  ...                1                      0
# 2      0      3  ...                1                      0
# 3      0      0  ...                1                      0
# 4      0      0  ...                0                      1
#
#    whois_registered_domain  domain_registration_length  domain_age  \
# ...

# %%
#df2 = df1.drop(df1.loc[: , "nb_hyperlinks" : "page_rank"].columns , axis = "columns")
#df2.head()

# %%
dummies = pd.get_dummies(df1.status)
dummies.head()
merged = pd.concat([df1,dummies] , axis='columns')
merged.head()
# Out:
#    length_url  length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  \
# 0          37               19   0        3           0      0      0       0
# 1          77               23   1        1           0      0      0       0
# 2         126               50   1        4           1      0      1       2
# 3          18               11   0        2           0      0      0       0
# 4          55               15   0        2           2      0      0       0
#
#    nb_or  nb_eq  ...  whois_registered_domain  domain_registration_length  \
# 0      0      0  ...                        0                          45
# 1      0      0  ...                        0                          77
# 2      0      3  ...                        0                          14
# 3      0      0  ...                        0                          62
# 4      0      0  ...                        0                         224
#
# ...

# %%
df_final = merged.drop("status", axis = "columns")
df_final.head()
# Out:
#    length_url  length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  \
# 0          37               19   0        3           0      0      0       0
# 1          77               23   1        1           0      0      0       0
# 2         126               50   1        4           1      0      1       2
# 3          18               11   0        2           0      0      0       0
# 4          55               15   0        2           2      0      0       0
#
#    nb_or  nb_eq  ...  domain_with_copyright  whois_registered_domain  \
# 0      0      0  ...                      1                        0
# 1      0      0  ...                      0                        0
# 2      0      3  ...                      0                        0
# 3      0      0  ...                      0                        0
# 4      0      0  ...                      1                        0
#
#    domain_registration_length  domain_age  web_traffic  dns_record  \
# ...

# %%
#diffrentiate categorical column and numeric column

# %%
cat_cols = {}
for i in df_final.iloc[:].columns:
    cat_cols[i] = df_final[i].nunique()/df_final[i].count() < 0.002
    

num_col = []
cat_col = []

for col in cat_cols.keys():
    if(cat_cols[col] == False):
        num_col.append(col)
    else:
        cat_col.append(col)

print("Number of numeric columns:",len(num_col))
print(num_col)
print("\n")
print("Number of categorical columns:",len(cat_col))
print(cat_col)
# Out:
# Number of numeric columns: 30
# ['length_url', 'length_hostname', 'nb_hyphens', 'nb_percent', 'ratio_digits_url', 'ratio_digits_host', 'length_words_raw', 'char_repeat', 'shortest_words_raw', 'shortest_word_host', 'shortest_word_path', 'longest_words_raw', 'longest_word_host', 'longest_word_path', 'avg_words_raw', 'avg_word_host', 'avg_word_path', 'nb_hyperlinks', 'ratio_intHyperlinks', 'ratio_extHyperlinks', 'nb_extCSS', 'ratio_extRedirection', 'ratio_extErrors', 'links_in_tags', 'ratio_intMedia', 'ratio_extMedia', 'safe_anchor', 'domain_registration_length', 'domain_age', 'web_traffic']
#
#
# Number of categorical columns: 59
# ...

# %%
#implement correlation matrix for features

# %%
import seaborn as sns
#from matplotlib.patches import Patch

# %%
cor_matrix = df_final[num_col].corr()

matrix = plt.figure(figsize=(12,12) , dpi=70)
mask = np.triu(np.ones_like(cor_matrix , dtype = bool))
sns.heatmap(cor_matrix , mask=mask , cmap = "YlGnBu" , robust=True , center=0 , square=True , linewidths=0.8)
plt.title("Correlation matrix of numeric features" , fontsize=12)
# Out:
# Text(0.5, 1.0, 'Correlation matrix of numeric features')

# %%
cor_matrix = df_final[cat_col].corr()

matrix = plt.figure(figsize=(12,12) , dpi=70)
mask = np.triu(np.ones_like(cor_matrix , dtype = bool))
sns.heatmap(cor_matrix , mask=mask , cmap = "YlGnBu" , robust=True , center=0 , square=True , linewidths=0.8)
plt.title("Correlation matrix of categorical features" , fontsize=12)
# Out:
# Text(0.5, 1.0, 'Correlation matrix of categorical features')

# %%
#how impactful one particular feature on the decision value based on the mean value

# %%
df_mean1 = df_final.groupby("legitimate")[num_col].mean().reset_index().T
df_mean1.rename(columns ={0:"Phishing", 1:"Legitimate"} , inplace = True)
plt.rcParams["axes.facecolor"] = "w"
#graph = df_mean1.plot(kind="bar" , title = "Distribution of average value over legitimate value")
graph = df_mean1.plot(kind="bar" , title = "Distribution of average value over legitimate value" , figsize=(10,5) , legend=True , fontsize = 10)
graph.set_xlabel("Numerical features" , fontsize=12)
graph.set_ylabel("Average values" , fontsize=12)
plt.show()

# %%
#df_mean = df_final.groupby("phishing")[cat_col].mean().reset_index().T
#df_mean.rename(columns ={0:"Phishing", 1:"Legitimate"} , inplace = True)
#plt.rcParams["axes.facecolor"] = "w"
#graph = df_mean1.plot(kind="bar" , title = "Distribution of average value over legitimate value")
#graph1 = df_mean.plot(kind="bar" , title = "Distribution of average value over phishing value" , figsize=(10,5) , legend=True , fontsize = 14)
#graph1.set_xlabel("Categorical Features" , fontsize=12)
#graph1.set_ylabel("Average values" , fontsize=12)
#plt.show()

# %%
#df_final["nb_or"].unique()

# %%
cols = list(df_final.columns)

# %%
df_x = df_final[cols[:-2]]
df_y = df_final['legitimate']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=42)

# %%
x_train.shape, y_train.shape
# Out:
# ((9144, 87), (9144,))

# %%
from sklearn.ensemble import RandomForestClassifier

clr = RandomForestClassifier(n_estimators=20)



#from sklearn.svm import SVR
#svr = SVR(kernel = 'linear', C=1)

# %% [markdown]
# ### Standardize data

# %%
from sklearn.preprocessing import StandardScaler

sc= StandardScaler().fit(x_train)

x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
clr.fit(x_train_std, y_train)
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
clr.score(x_train_std , y_train)
# Out:
# 0.9998906386701663

# %%
clr.predict(x_test_std)
# Out:
# array([1, 1, 1, ..., 0, 1, 0], dtype=uint8)

# %%
clr.score(x_test_std , y_test)
# Out:
# 0.9636920384951881
